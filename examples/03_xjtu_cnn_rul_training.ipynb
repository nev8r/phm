# %% [markdown]
# # XJTU-SY CNN RUL Training
#
# Train a small CNN on demo XJTU-SY raw vibration windows. The notebook writes predictions and metrics under `outputs/examples` or `BEARING_EXAMPLE_OUTPUT_ROOT`.

# %%
from USTC.SSE.BearingPrediction.api import CNN, XJTULoader
from USTC.SSE.BearingPrediction.examples import run_xjtu_cnn_rul_training

result = run_xjtu_cnn_rul_training()
print(result)
assert result["status"] == "OK"
assert "mae" in result["metrics"]
# Out:
# {'status': 'OK', 'metrics': {'mae': 20.075570225715637, 'rmse': 34.51658614059919}, 'prediction_path': 'outputs/examples/xjtu_cnn_rul_training/predictions.csv'}
