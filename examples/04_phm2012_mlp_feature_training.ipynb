# %% [markdown]
# # PHM2012 MLP Feature Training
#
# Train a small MLP on demo PHM2012/FEMTO feature windows. This uses extracted time/frequency features rather than raw signal windows.

# %%
from USTC.SSE.BearingPrediction.api import MLP, PHM2012Loader
from USTC.SSE.BearingPrediction.examples import run_phm2012_mlp_feature_training

result = run_phm2012_mlp_feature_training()
print(result)
assert result["status"] == "OK"
assert "rmse" in result["metrics"]
