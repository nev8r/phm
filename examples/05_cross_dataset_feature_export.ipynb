# %% [markdown]
# # Cross-Dataset Feature Export
#
# Create comparable feature tables from demo XJTU-SY and PHM2012 entities for quick inspection or downstream experiments.

# %%
from USTC.SSE.BearingPrediction.examples import run_cross_dataset_feature_export

result = run_cross_dataset_feature_export()
print(result)
assert result["status"] == "OK"
assert result["xjtu_rows"] > 0
assert result["phm2012_rows"] > 0
