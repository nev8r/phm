# %% [markdown]
# # XJTU-SY Loader Overview
#
# Generate a tiny XJTU-SY-like fixture and inspect the parsed entity, metadata, channels, timestamps, and RUL labels.

# %%
from USTC.SSE.BearingPrediction.api import XJTULoader
from USTC.SSE.BearingPrediction.examples import run_xjtu_loader_overview

result = run_xjtu_loader_overview()
print(result)
assert result["status"] == "OK"
assert "Horizontal Vibration" in result["channels"]
