# %% [markdown]
# # PHM2012 Loader Overview
#
# Generate a tiny PHM2012/FEMTO-like fixture and inspect acceleration files, temperature files, timestamps, and RUL labels.

# %%
from USTC.SSE.BearingPrediction.api import PHM2012Loader
from USTC.SSE.BearingPrediction.examples import run_phm2012_loader_overview

result = run_phm2012_loader_overview()
print(result)
assert result["status"] == "OK"
assert "Temperature" in result["channels"]
