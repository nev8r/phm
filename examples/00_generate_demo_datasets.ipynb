# %% [markdown]
# # Generate Demo Datasets
#
# Create tiny XJTU-SY and PHM2012 directory fixtures, then use them in the other notebooks.

# %%
from USTC.SSE.BearingPrediction.examples import run_generate_demo_datasets

result = run_generate_demo_datasets()
print(result)
assert result["status"] == "OK"
# Out:
# {'status': 'OK', 'xjtu_root': 'outputs/examples/demo_data/XJTU-SY_Bearing_Datasets', 'phm2012_root': 'outputs/examples/demo_data/FEMTO'}
